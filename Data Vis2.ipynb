# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_iris

# %%
data = load_iris(as_frame = True).frame
data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
data = load_iris(as_frame = True).frame
data.head()

x = data['target'].value_counts().keys()
height = data['target'].value_counts().values

plt.bar(x,height)
plt.title('Bar Chart', color = 'Red', fontweight = 'bold')
plt.xticks(x)
plt.xlabel('X - Axis', color = 'Green')
plt.ylabel('Y - Axis' , color = 'Green')

plt.show()

# %% [markdown]
# # Histogram

# %%
x = data.select_dtypes(float)
x.dtypes
# Out:
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# dtype: object

# %%
x.hist()
plt.show()

# %%
plt.hist(x['sepal length (cm)'])
print(x['sepal length (cm)'].skew())
plt.title('Histogram', color = 'Purple', fontweight = 'bold', fontsize = 14)
plt.show()
# Out:
# 0.3149109566369728

# %%
fig , axes = plt.subplots(2,2)

axes[0][0].hist(x['petal length (cm)'])
axes[0][0].set_title('petal length (cm)', color = 'Purple')

axes[0][1].hist(x['sepal length (cm)'])
axes[0][1].set_title('sepal length (cm)', color = 'Purple')

axes[1][0].hist(x['petal width (cm)'])
axes[1][0].set_title('petal width (cm)', color = 'Purple')

axes[1][1].hist(x['sepal width (cm)'])
axes[1][1].set_title('sepal width (cm)', color = 'Purple')

plt.tight_layout()
plt.show()

# %%
#plt.subplot(nrows,ncols,pos)

plt.figure()

for i in range(len(x.columns)):
    plt.subplot(5,2,i+1)
    plt.hist(x[x.columns[i]])
    plt.title(x.columns[i]) 

plt.tight_layout()
plt.show()

# %%
Data = sns.load_dataset('penguins')

# %%
Data
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
x = Data['species'].value_counts().keys()
height = Data['species'].value_counts().values

plt.bar(x,height)
plt.title('Species Distribution ', color = 'Red', fontweight = 'bold', fontsize = 12)
plt.xticks(x)
plt.xlabel('Species', color = 'Green')
plt.ylabel('Y - Axis' , color = 'Green')

plt.show()

# %%
x = Data.select_dtypes(float)
x.dtypes
# Out:
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# dtype: object

# %%
x.hist()
plt.show()

# %%
plt.hist(x['bill_length_mm'])
print(x['bill_length_mm'].skew())
plt.title('Histogram', color = 'Purple', fontweight = 'bold', fontsize = 14)
plt.show()
# Out:
# 0.05311806699132413

# %%
fig , axes = plt.subplots(2,2)

axes[0][0].hist(x['bill_length_mm'])
axes[0][0].set_title('bill_length_mm', color = 'Orange')

axes[0][1].hist(x['bill_depth_mm'])
axes[0][1].set_title('bill_depth_mm', color = 'Orange')

axes[1][0].hist(x['flipper_length_mm'])
axes[1][0].set_title('flipper_length_mm', color = 'Orange')

axes[1][1].hist(x['body_mass_g'])
axes[1][1].set_title('body_mass_g', color = 'Orange')

plt.tight_layout()
plt.show()

# %%
num = 3
while num >=1:
    print(num, end = '')
    num-=1
# Out:
# 321

# %%
c = 0
for i in Data.columns:
    if Data[i].dtype == object:
        x, height = Data[i].value_counts().keys(),Data[i].value_counts().values
        plt.barh(x, height)  
        plt.show()
    else:
        plt.subplot(10,3,c+1)
        plt.hist(Data[i])
        plt.show()
    
    c+=1


plt.tight_layout()

# %%
Data2 = data.select_dtypes('number').iloc[:,:-1]

for col in Data2.columns:
    plt.boxplot(Data2[col])
    plt.title(col)
    plt.show()

# %%
explode = (0.2,0)
plt.pie(height, labels = x , autopct = '%1.1f%%', explode = explode)
plt.title('Gender  Distribution')
plt.show()
plt.tight_layout()

# %%
Data = Data.select_dtypes(object)

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   species  344 non-null    object
#  1   island   344 non-null    object
#  2   sex      333 non-null    object
# dtypes: object(3)
# memory usage: 8.2+ KB

# %%
import random
obj_columns = Data.select_dtypes(object).columns
for col in obj_columns:
    num = random.randint(1,25)
    even = num % 2 == 0
    if even:
        labels = data[col].value_counts().keys()
        x = data[col].value_counts().values
        plt.pie(x, labels = labels)
        plt.title(f'num : {col}')
        plt.show()
    else:
        x,height = data[col].vaue_counts().keys(),data[col].value_counts().values
        plt.bar(x,height)
        plt.title(f'num : {col}')
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'species'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[207], line 7
#       5 even = num % 2 == 0
#       6 if even:
# ...
